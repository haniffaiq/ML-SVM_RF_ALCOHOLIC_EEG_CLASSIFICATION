# %%
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import itertools


# Membaca data dari file CSV
df = pd.read_csv('gldm_features_Data_Normal.csv')

# Membagi data menjadi beberapa dataframe berdasarkan arah
directions = ['0', '45', '90', '135']
dataframes = []

for direction in directions:
    cols = [f'Contrast_{direction}', f'ASM_{direction}', f'Entropy_{direction}', f'Mean_{direction}',
            f'IDM_{direction}']
    df_direction = df[['Image'] + cols]
    df_direction['Label'] = df.index.map(lambda x: 0 if x <= 600 else 1)
    dataframes.append(df_direction)
# Out:
# C:\Users\hanif\AppData\Local\Temp\ipykernel_23328\1184848898.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_direction['Label'] = df.index.map(lambda x: 0 if x <= 600 else 1)
# C:\Users\hanif\AppData\Local\Temp\ipykernel_23328\1184848898.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_direction['Label'] = df.index.map(lambda x: 0 if x <= 600 else 1)
# C:\Users\hanif\AppData\Local\Temp\ipykernel_23328\1184848898.py:19: SettingWithCopyWarning:
# ...

# %%
fig, axes = plt.subplots(len(directions), len(dataframes[0].columns) - 2, figsize=(16, 12))

# Visualize each direction
for i, direction in enumerate(directions):
    df_direction = dataframes[i]

    # Box plots for each GLDM parameter
    for j, column in enumerate(df_direction.columns[1:-1]):  # Exclude 'Image' and 'Label' columns
        ax = axes[i, j]
        sns.boxplot(x='Label', y=column, hue='Label', data=df_direction, ax=ax)
        ax.set_title(f'Box Plot of {column} in Direction {direction}')
        ax.legend(title='Label')
        ax.set_xlabel('Label')
        ax.set_ylabel(column)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(len(directions), len(dataframes[0].columns) - 2, figsize=(16, 12))

# Visualize each direction
for i, direction in enumerate(directions):
    df_direction = dataframes[i]

    # Histogram plots for each GLDM parameter
    for j, column in enumerate(df_direction.columns[1:-1]):  # Exclude 'Image' and 'Label' columns
        ax = axes[i, j]
        histplot = sns.histplot(data=df_direction, x=column, hue='Label', multiple='stack', ax=ax)
        ax.set_title(f'Histogram Plot of {column} in Direction {direction}')

        # Create legend handles and labels
        handles, labels = histplot.get_legend_handles_labels()
        handles = [h[0] for h in handles]  # Extract the actual artists from the LegendHandles tuple
        ax.legend(handles, labels, title='Label')

        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Membaca data dari file CSV
df2 = pd.read_csv('gldm_features_Data_Enhance.csv')

# Membagi data menjadi beberapa dataframe berdasarkan arah
directions2 = ['0', '45', '90', '135']
dataframes2 = []

for direction in directions:
    cols = [f'Contrast_{direction}', f'ASM_{direction}', f'Entropy_{direction}', f'Mean_{direction}',
            f'IDM_{direction}']
    df_direction2 = df[['Image'] + cols]
    df_direction2['Label'] = df.index.map(lambda x: 0 if x <= 600 else 1)
    dataframes2.append(df_direction)
# Out:
# C:\Users\hanif\AppData\Local\Temp\ipykernel_23328\2780159455.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_direction2['Label'] = df.index.map(lambda x: 0 if x <= 600 else 1)
# C:\Users\hanif\AppData\Local\Temp\ipykernel_23328\2780159455.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_direction2['Label'] = df.index.map(lambda x: 0 if x <= 600 else 1)
# C:\Users\hanif\AppData\Local\Temp\ipykernel_23328\2780159455.py:12: SettingWithCopyWarning:
# ...

# %%
fig, axes = plt.subplots(len(directions2), len(dataframes2[0].columns) - 2, figsize=(16, 12))

# Visualize each direction
for i, direction2 in enumerate(directions2):
    df_direction2 = dataframes2[i]

    # Box plots for each GLDM parameter
    for j, column in enumerate(df_direction2.columns[1:-1]):  # Exclude 'Image' and 'Label' columns
        ax = axes[i, j]
        sns.boxplot(x='Label', y=column, hue='Label', data=df_direction, ax=ax)
        ax.set_title(f'Box Plot of {column} in Direction {direction2}')
        ax.legend(title='Label')
        ax.set_xlabel('Label')
        ax.set_ylabel(column)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(len(directions2), len(dataframes2[0].columns) - 2, figsize=(16, 12))

# Visualize each direction
for i, direction2 in enumerate(directions2):
    df_direction2 = dataframes2[i]

    # Histogram plots for each GLDM parameter
    for j, column in enumerate(df_direction2.columns[1:-1]):  # Exclude 'Image' and 'Label' columns
        ax = axes[i, j]
        histplot = sns.histplot(data=df_direction, x=column, hue='Label', multiple='stack', ax=ax)
        ax.set_title(f'Histogram Plot of {column} in Direction {direction2}')

        # Create legend handles and labels
        handles, labels = histplot.get_legend_handles_labels()
        handles = [h[0] for h in handles]  # Extract the actual artists from the LegendHandles tuple
        ax.legend(handles, labels, title='Label')

        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()
